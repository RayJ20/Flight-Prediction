# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_train=pd.read_excel('FPdatatrain.xlsx')
df_train
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
df_test=pd.read_excel('FPdatatest.xlsx')
df_test
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0           Jet Airways       6/06/2019     Delhi      Cochin
# 1                IndiGo      12/05/2019   Kolkata    Banglore
# 2           Jet Airways      21/05/2019     Delhi      Cochin
# 3     Multiple carriers      21/05/2019     Delhi      Cochin
# 4              Air Asia      24/06/2019  Banglore       Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                 Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0     DEL → BOM → COK    17:30  04:25 07 Jun  10h 55m      1 stop
# 1     CCU → MAA → BLR    06:20         10:20       4h      1 stop
# ...

# %%
df=pd.concat([df_train,df_test])

# %%
df
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0                IndiGo      24/03/2019  Banglore   New Delhi
# 1             Air India       1/05/2019   Kolkata    Banglore
# 2           Jet Airways       9/06/2019     Delhi      Cochin
# 3                IndiGo      12/05/2019   Kolkata    Banglore
# 4                IndiGo      01/03/2019  Banglore   New Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                 BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1     CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
df.isnull().sum()
# Out:
# Airline               0
# Date_of_Journey       0
# Source                0
# Destination           0
# Route                 1
# Dep_Time              0
# Arrival_Time          0
# Duration              0
# Total_Stops           1
# Additional_Info       0
# Price              2671
# dtype: int64

# %%
df['Airline'].unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
df['Airline']=df['Airline'].map({'IndiGo':1, 'Air India':2, 'Jet Airways':3, 'SpiceJet':4,
       'Multiple carriers':5, 'GoAir':6, 'Vistara':7, 'Air Asia':8,
       'Vistara Premium economy':9, 'Jet Airways Business':10,
       'Multiple carriers Premium economy':11, 'Trujet':12})

# %%
df
# Out:
#       Airline Date_of_Journey    Source Destination                  Route  \
# 0           1      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1           2       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2           3       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3           1      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4           1      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
# ...       ...             ...       ...         ...                    ...
# 2666        2       6/06/2019   Kolkata    Banglore        CCU → DEL → BLR
# 2667        1      27/03/2019   Kolkata    Banglore              CCU → BLR
# 2668        3       6/03/2019     Delhi      Cochin        DEL → BOM → COK
# 2669        2       6/03/2019     Delhi      Cochin        DEL → BOM → COK
# 2670        5      15/06/2019     Delhi      Cochin        DEL → BOM → COK
#
# ...

# %%
df['Date']=df['Date_of_Journey'].str.split('/').str[0]
df['Month']=df['Date_of_Journey'].str.split('/').str[1]
df['Year']=df['Date_of_Journey'].str.split('/').str[2]

# %%
df.head()
# Out:
#    Airline Date_of_Journey    Source Destination                  Route  \
# 0        1      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1        2       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2        3       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3        1      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4        1      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info    Price Date  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897.0   24
# 1    05:50         13:15   7h 25m     2 stops         No info   7662.0    1
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882.0    9
# 3    18:05         23:30   5h 25m      1 stop         No info   6218.0   12
# 4    16:50         21:35   4h 45m      1 stop         No info  13302.0   01
#
#   Month  Year
# 0    03  2019
# 1    05  2019
# 2    06  2019
# ...

# %%
df['Date']=df['Date'].astype(int)
df['Month']=df['Month'].astype(int)
df['Year']=df['Year'].astype(int)

# %%
df.drop('Date_of_Journey',axis=1,inplace=True)

# %%
df.head()
# Out:
#    Airline    Source Destination                  Route Dep_Time  \
# 0        1  Banglore   New Delhi              BLR → DEL    22:20
# 1        2   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2        3     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3        1   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4        1  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#    Arrival_Time Duration Total_Stops Additional_Info    Price  Date  Month  \
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897.0    24      3
# 1         13:15   7h 25m     2 stops         No info   7662.0     1      5
# 2  04:25 10 Jun      19h     2 stops         No info  13882.0     9      6
# 3         23:30   5h 25m      1 stop         No info   6218.0    12      5
# 4         21:35   4h 45m      1 stop         No info  13302.0     1      3
#
#    Year
# 0  2019
# 1  2019
# 2  2019
# 3  2019
# 4  2019

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 2670
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  int64
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Route            13353 non-null  object
#  4   Dep_Time         13354 non-null  object
#  5   Arrival_Time     13354 non-null  object
#  6   Duration         13354 non-null  object
#  7   Total_Stops      13353 non-null  object
#  8   Additional_Info  13354 non-null  object
#  9   Price            10683 non-null  float64
#  10  Date             13354 non-null  int32
#  11  Month            13354 non-null  int32
#  12  Year             13354 non-null  int32
# dtypes: float64(1), int32(3), int64(1), object(8)
# memory usage: 1.3+ MB

# %%
df['Arrival_Time']=df['Arrival_Time'].str.split(' ').str[0]

# %%
df.head()
# Out:
#    Airline    Source Destination                  Route Dep_Time Arrival_Time  \
# 0        1  Banglore   New Delhi              BLR → DEL    22:20        01:10
# 1        2   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50        13:15
# 2        3     Delhi      Cochin  DEL → LKO → BOM → COK    09:25        04:25
# 3        1   Kolkata    Banglore        CCU → NAG → BLR    18:05        23:30
# 4        1  Banglore   New Delhi        BLR → NAG → DEL    16:50        21:35
#
#   Duration Total_Stops Additional_Info    Price  Date  Month  Year
# 0   2h 50m    non-stop         No info   3897.0    24      3  2019
# 1   7h 25m     2 stops         No info   7662.0     1      5  2019
# 2      19h     2 stops         No info  13882.0     9      6  2019
# 3   5h 25m      1 stop         No info   6218.0    12      5  2019
# 4   4h 45m      1 stop         No info  13302.0     1      3  2019

# %%
df['Arrival_hour']=df['Arrival_Time'].str.split(':').str[0]
df['Arrival_min']=df['Arrival_Time'].str.split(':').str[1]

# %%
df.drop('Arrival_Time',axis=1,inplace=True)

# %%
df.head()
# Out:
#    Airline    Source Destination                  Route Dep_Time Duration  \
# 0        1  Banglore   New Delhi              BLR → DEL    22:20   2h 50m
# 1        2   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50   7h 25m
# 2        3     Delhi      Cochin  DEL → LKO → BOM → COK    09:25      19h
# 3        1   Kolkata    Banglore        CCU → NAG → BLR    18:05   5h 25m
# 4        1  Banglore   New Delhi        BLR → NAG → DEL    16:50   4h 45m
#
#   Total_Stops Additional_Info    Price  Date  Month  Year Arrival_hour  \
# 0    non-stop         No info   3897.0    24      3  2019           01
# 1     2 stops         No info   7662.0     1      5  2019           13
# 2     2 stops         No info  13882.0     9      6  2019           04
# 3      1 stop         No info   6218.0    12      5  2019           23
# 4      1 stop         No info  13302.0     1      3  2019           21
#
#   Arrival_min
# 0          10
# 1          15
# 2          25
# 3          30
# 4          35

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 2670
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  int64
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Route            13353 non-null  object
#  4   Dep_Time         13354 non-null  object
#  5   Duration         13354 non-null  object
#  6   Total_Stops      13353 non-null  object
#  7   Additional_Info  13354 non-null  object
#  8   Price            10683 non-null  float64
#  9   Date             13354 non-null  int32
#  10  Month            13354 non-null  int32
#  11  Year             13354 non-null  int32
#  12  Arrival_hour     13354 non-null  object
#  13  Arrival_min      13354 non-null  object
# dtypes: float64(1), int32(3), int64(1), object(9)
# memory usage: 1.4+ MB

# %%
df['Arrival_hour']=df['Arrival_hour'].astype(int)
df['Arrival_min']=df['Arrival_min'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 2670
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  int64
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Route            13353 non-null  object
#  4   Dep_Time         13354 non-null  object
#  5   Duration         13354 non-null  object
#  6   Total_Stops      13353 non-null  object
#  7   Additional_Info  13354 non-null  object
#  8   Price            10683 non-null  float64
#  9   Date             13354 non-null  int32
#  10  Month            13354 non-null  int32
#  11  Year             13354 non-null  int32
#  12  Arrival_hour     13354 non-null  int32
#  13  Arrival_min      13354 non-null  int32
# dtypes: float64(1), int32(5), int64(1), object(7)
# memory usage: 1.3+ MB

# %%
df['Departure_hour']=df['Dep_Time'].str.split(':').str[0]
df['Departure_min']=df['Dep_Time'].str.split(':').str[1]

# %%
df['Departure_hour']=df['Departure_hour'].astype(int)
df['Departure_min']=df['Departure_min'].astype(int)

# %%
df.drop('Dep_Time',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 2670
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  int64
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Route            13353 non-null  object
#  4   Duration         13354 non-null  object
#  5   Total_Stops      13353 non-null  object
#  6   Additional_Info  13354 non-null  object
#  7   Price            10683 non-null  float64
#  8   Date             13354 non-null  int32
#  9   Month            13354 non-null  int32
#  10  Year             13354 non-null  int32
#  11  Arrival_hour     13354 non-null  int32
#  12  Arrival_min      13354 non-null  int32
#  13  Departure_hour   13354 non-null  int32
#  14  Departure_min    13354 non-null  int32
# dtypes: float64(1), int32(7), int64(1), object(6)
# memory usage: 1.3+ MB

# %%
df1=df.copy()
df1.head(10)
# Out:
#    Airline    Source Destination                  Route Duration Total_Stops  \
# 0        1  Banglore   New Delhi              BLR → DEL   2h 50m    non-stop
# 1        2   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m     2 stops
# 2        3     Delhi      Cochin  DEL → LKO → BOM → COK      19h     2 stops
# 3        1   Kolkata    Banglore        CCU → NAG → BLR   5h 25m      1 stop
# 4        1  Banglore   New Delhi        BLR → NAG → DEL   4h 45m      1 stop
# 5        4   Kolkata    Banglore              CCU → BLR   2h 25m    non-stop
# 6        3  Banglore   New Delhi        BLR → BOM → DEL  15h 30m      1 stop
# 7        3  Banglore   New Delhi        BLR → BOM → DEL   21h 5m      1 stop
# 8        3  Banglore   New Delhi        BLR → BOM → DEL  25h 30m      1 stop
# 9        5     Delhi      Cochin        DEL → BOM → COK   7h 50m      1 stop
#
#                Additional_Info    Price  Date  Month  Year  Arrival_hour  \
# ...

# %%
Des=df1['Route'].str.split('→').str[-1]

# %%
Des
# Out:
# 0        DEL
# 1        BLR
# 2        COK
# 3        BLR
# 4        DEL
#         ...
# 2666     BLR
# 2667     BLR
# 2668     COK
# 2669     COK
# 2670     COK
# Name: Route, Length: 13354, dtype: object

# %%
df['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
df['Total_Stops']=df['Total_Stops'].map({'non-stop':0,'1 stop':1,'2 stops':2,'3 stops':3,'4 stops':4,'NaN':0})

# %%
df.head()
# Out:
#    Airline    Source Destination                  Route Duration  Total_Stops  \
# 0        1  Banglore   New Delhi              BLR → DEL   2h 50m          0.0
# 1        2   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m          2.0
# 2        3     Delhi      Cochin  DEL → LKO → BOM → COK      19h          2.0
# 3        1   Kolkata    Banglore        CCU → NAG → BLR   5h 25m          1.0
# 4        1  Banglore   New Delhi        BLR → NAG → DEL   4h 45m          1.0
#
#   Additional_Info    Price  Date  Month  Year  Arrival_hour  Arrival_min  \
# 0         No info   3897.0    24      3  2019             1           10
# 1         No info   7662.0     1      5  2019            13           15
# 2         No info  13882.0     9      6  2019             4           25
# 3         No info   6218.0    12      5  2019            23           30
# 4         No info  13302.0     1      3  2019            21           35
#
#    Departure_hour  Departure_min
# ...

# %%
df1=df1.dropna(subset='Total_Stops')

# %%
df1.isnull().sum()
# Out:
# Airline               0
# Source                0
# Destination           0
# Route                 0
# Duration              0
# Total_Stops           0
# Additional_Info       0
# Price              2671
# Date                  0
# Month                 0
# Year                  0
# Arrival_hour          0
# Arrival_min           0
# Departure_hour        0
# Departure_min         0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Airline               0
# Source                0
# Destination           0
# Route                 1
# Duration              0
# Total_Stops           1
# Additional_Info       0
# Price              2671
# Date                  0
# Month                 0
# Year                  0
# Arrival_hour          0
# Arrival_min           0
# Departure_hour        0
# Departure_min         0
# dtype: int64

# %%
df[df['Total_Stops']=='NaN']
# Out:
# Empty DataFrame
# Columns: [Airline, Source, Destination, Route, Duration, Total_Stops, Additional_Info, Price, Date, Month, Year, Arrival_hour, Arrival_min, Departure_hour, Departure_min]
# Index: []

# %%
df[df['Total_Stops'].isnull()]
# Out:
#       Airline Source Destination Route Duration  Total_Stops Additional_Info  \
# 9039        2  Delhi      Cochin   NaN  23h 40m          NaN         No info
#
#        Price  Date  Month  Year  Arrival_hour  Arrival_min  Departure_hour  \
# 9039  7480.0     6      5  2019             9           25               9
#
#       Departure_min
# 9039             45

# %%
df.isnull().sum()
# Out:
# Airline               0
# Source                0
# Destination           0
# Route                 1
# Duration              0
# Total_Stops           1
# Additional_Info       0
# Price              2671
# Date                  0
# Month                 0
# Year                  0
# Arrival_hour          0
# Arrival_min           0
# Departure_hour        0
# Departure_min         0
# dtype: int64

# %%
df['Duration_hour']=df['Duration'].str.split(' ').str[0].str.split('h').str[0]
df['Duration_min']=df['Duration'].str.split(' ').str[1].str.split('m').str[0]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 2670
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  int64
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Route            13353 non-null  object
#  4   Duration         13354 non-null  object
#  5   Total_Stops      13353 non-null  float64
#  6   Additional_Info  13354 non-null  object
#  7   Price            10683 non-null  float64
#  8   Date             13354 non-null  int32
#  9   Month            13354 non-null  int32
#  10  Year             13354 non-null  int32
#  11  Arrival_hour     13354 non-null  int32
#  12  Arrival_min      13354 non-null  int32
#  13  Departure_hour   13354 non-null  int32
#  14  Departure_min    13354 non-null  int32
#  15  Duration_hour    13354 non-null  object
#  16  Duration_min     12068 non-null  object
# ...
